# %% [markdown]
# <a href="https://colab.research.google.com/github/Demshin82/AI-architect-/blob/master/%D0%92%D1%8B%D1%81%D1%88%D0%B0%D1%8F_%D0%BC%D0%B0%D1%82%D0%B5%D0%BC%D0%B0%D1%82%D0%B8%D0%BA%D0%B0_%D0%94%D0%97_1_%D0%9C%D0%B0%D1%82%D1%80%D0%B8%D1%86%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
A = np.matrix([[6, -8, 3]])
B = np.matrix([[1],[1],[4]])
C = np.matrix([[-3, -7],
               [-10, 6],
               [0, -6],
               [-1, -3]])
D = np.matrix([[-8, 9],
               [4, -2]])

# %%
AB = A*B
CD = C*D
print('произведение матриц А и В =', AB)
print('произведение матриц С и D =')
print( CD)
# Out:
# произведение матриц А и В = [[10]]
# произведение матриц С и D =
# [[  -4  -13]
#  [ 104 -102]
#  [ -24   12]
#  [  -4   -3]]
